# %%
pip install poetry
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/249.9 kB ? eta -:--:--
#    ---------------------- ----------------- 143.4/249.9 kB 4.2 MB/s eta 0:00:01
#    ------------------------------------ --- 225.3/249.9 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  245.8/249.9 kB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 249.9/249.9 kB 2.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/309.5 kB ? eta -:--:--
#    ------------------- -------------------- 153.6/309.5 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  307.2/309.5 kB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 309.5/309.5 kB 3.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/78.7 kB ? eta -:--:--
#    ---------------------------------------- 78.7/78.7 kB 4.3 MB/s eta 0:00:00
# ...

# %%
pip install pdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/258.5 kB ? eta -:--:--
#    ---------------------- ----------------- 143.4/258.5 kB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 258.5/258.5 kB 4.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/75.6 kB ? eta -:--:--
#    ---------------------------------------- 75.6/75.6 kB 4.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/77.9 kB ? eta -:--:--
#    ---------------------------------------- 77.9/77.9 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/240.7 kB ? eta -:--:--
#    ---------------------------------------- 240.7/240.7 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/47.0 kB ? eta -:--:--
#    ---------------------------------------- 47.0/47.0 kB 2.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/42.3 kB ? eta -:--:--
# ...
